# %% [markdown]
# <a href="https://colab.research.google.com/github/Vidalic740/Random-Forests-Algorithm/blob/main/RandomForests.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
sensor_data = pd.read_csv('/content/drive/MyDrive/Data/sensor_data.csv')
maintenance_records = pd.read_csv('/content/drive/MyDrive/Data/maintenance_records.csv')

# %%
df = pd.merge(sensor_data, maintenance_records, on='Equipment_ID')

features = df[['Equipment_ID']]
target = df['Failure_Flag']

X_train, X_test
# Out:
# (    Equipment_ID       Timestamp_x  Vibration  Temperature  Pressure  Current  \
#  10             1  15/11/2023 00:03          3           27       102       12
#  58             3  15/11/2023 00:12          2           24        91        9
#  72             3  15/11/2023 00:15          5           27        94       12
#  59             3  15/11/2023 00:12          2           24        91        9
#  45             2  15/11/2023 00:10          8           28        99       13
#  67             3  15/11/2023 00:14          4           26        93       11
#  19             1  15/11/2023 00:04          4           28       103       13
#  44             2  15/11/2023 00:09          7           27        98       12
#  31             2  15/11/2023 00:07          5           25        96       10
#  18             1  15/11/2023 00:04          4           28       103       13
#  13             1  15/11/2023 00:03          3           27       102       12
# ...
